# %% [markdown]
# # My Jupiter Notebook on IBM Watson Studio

# %% [markdown]
# **Kothainayahi Shanmugam**
# Medical Coder to Data Engineer

# %% [markdown]
# *I am interested in Data Science because I am interested in a new career.*

# %% [markdown]
# ###The following formula tests addition.###

# %%
5+5
# Out:
# 10

# %% [markdown]
# 1. Number one
# 2. Number two
# 3. Number three
# 4. Number four
# 5. Number five
#
# ~~This text is a mistake~~
#
# > This sentence is an example of quote
#
# - Python
# - SQL
# - Scala
# - R
# - Github
